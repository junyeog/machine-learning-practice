# %%
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://junyeog: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@github.com/junyeog/machine-learning-practice.git
# Out:
# Cloning into 'machine-learning-practice'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.

# %%
# !cd 2025-1

# %%
pwd
# Out:
# '/content'

# %%
# !git config --global user.email 'junhuok05@gmail.com'
# !git config --global user.name 'junyeog'

# %%
# !git config --list
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.email=junhuok05@gmail.com
# user.name=junyeog

# %%
# !cd machine-learning-practice/

# %%
ll
# Out:
# total 20
# drwxr-xr-x 2 root 4096 Mar 12 00:56 2025-1/
# drwx------ 6 root 4096 Mar 12 00:55 drive/
# drwxr-xr-x 3 root 4096 Mar 12 01:05 machine-learning-practice/
# drwxr-xr-x 2 root 4096 Mar 12 00:57 ml/
# drwxr-xr-x 1 root 4096 Mar  5 14:26 sample_data/

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git
