# %% [markdown]
# <a href="https://colab.research.google.com/github/junyeog/machine-learning-practice/blob/main/250604_random_image_segrmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 라이브러리 불러오기

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from tensorflow.keras import backend as K

# %% [markdown]
# # 랜덤 이미지 생성 및 확인

# %%
def generate_p_data(num_samples=100, img_size=128):

    X = np.random.choice(
        [0.8, 0.4, 0.1],  # 이미지 픽셀 타입
        size=(num_samples, img_size, img_size, 1),
        p=[0.05, 0.25, 0.7]  # 픽셀 비율 설정
    )
    Y = (X > 0.5).astype(np.float32)  # Threshold를 기준으로 마스크 생성
    return X, Y

# %%
sample = generate_p_data(num_samples=100, img_size=128)
sample[0].shape
# Out:
# (100, 128, 128, 1)

# %%
sample[1].shape
# Out:
# (100, 128, 128, 1)

# %%
#sample 출력
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(sample[0][i].squeeze(), cmap='gray')
    plt.axis('off')
plt.show()

# %%
X, Y = generate_p_data(num_samples=200, img_size=128)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# # 세그멘테이션 성능 평가 지표

# %%
def dice_coef(y_true, y_pred, smooth=100):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)

    intersection = K.sum(y_true_flatten * y_pred_flatten)
    union = K.sum(y_true_flatten) + K.sum(y_pred_flatten)
    return (2 * intersection + smooth) / (union + smooth)

def dice_loss(y_true, y_pred, smooth=100):
    return -dice_coef(y_true, y_pred, smooth)

def iou_coef(y_true, y_pred, smooth=100):
    intersection = K.sum(y_true * y_pred)
    sum = K.sum(y_true + y_pred)
    iou = (intersection + smooth) / (sum - intersection + smooth)
    return iou

# %% [markdown]
# # 모델 정의

# %%
def unet_model(input_size=(128, 128, 1)):
    inputs = Input(input_size)

    # 다운샘플링
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)#CNN
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)#maxpooling

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    # Bottleneck
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)

    # 업샘플링
    u1 = UpSampling2D((2, 2))(c4)
    u1 = concatenate([u1, c3]) #SkipConnection
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(u1)
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(c5)

    u2 = UpSampling2D((2, 2))(c5)
    u2 = concatenate([u2, c2])
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(u2)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(c6)

    u3 = UpSampling2D((2, 2))(c6)
    u3 = concatenate([u3, c1])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(u3)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(c7)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c7)

    model = Model(inputs, outputs)
    return model

# %%
model = unet_model()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',iou_coef,dice_coef])

# %% [markdown]
# # 모델 학습 및 성능 평가

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=10, batch_size=16)
# Out:
# Epoch 1/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.8319 - dice_coef: 0.0755 - iou_coef: 0.0404 - loss: 0.5574 - val_accuracy: 0.9501 - val_dice_coef: 0.0463 - val_iou_coef: 0.0264 - val_loss: 0.2167
# Epoch 2/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 184ms/step - accuracy: 0.9503 - dice_coef: 0.0534 - iou_coef: 0.0291 - loss: 0.2215 - val_accuracy: 0.9501 - val_dice_coef: 0.0516 - val_iou_coef: 0.0288 - val_loss: 0.2119
# Epoch 3/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9500 - dice_coef: 0.0534 - iou_coef: 0.0291 - loss: 0.2132 - val_accuracy: 0.9501 - val_dice_coef: 0.0552 - val_iou_coef: 0.0307 - val_loss: 0.2082
# Epoch 4/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.9499 - dice_coef: 0.0550 - iou_coef: 0.0300 - loss: 0.2076 - val_accuracy: 0.9501 - val_dice_coef: 0.0592 - val_iou_coef: 0.0328 - val_loss: 0.2013
# Epoch 5/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.9499 - dice_coef: 0.0588 - iou_coef: 0.0321 - loss: 0.1991 - val_accuracy: 0.9501 - val_dice_coef: 0.0677 - val_iou_coef: 0.0375 - val_loss: 0.1884
# Epoch 6/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.9501 - dice_coef: 0.0723 - iou_coef: 0.0394 - loss: 0.1834 - val_accuracy: 0.9501 - val_dice_coef: 0.1105 - val_iou_coef: 0.0608 - val_loss: 0.1618
# Epoch 7/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 0.9501 - dice_coef: 0.1308 - iou_coef: 0.0722 - loss: 0.1503 - val_accuracy: 0.9501 - val_dice_coef: 0.2339 - val_iou_coef: 0.1356 - val_loss: 0.1075
# Epoch 8/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9500 - dice_coef: 0.3190 - iou_coef: 0.1941 - loss: 0.0914 - val_accuracy: 0.9501 - val_dice_coef: 0.5133 - val_iou_coef: 0.3479 - val_loss: 0.0568
# Epoch 9/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.9547 - dice_coef: 0.5446 - iou_coef: 0.3767 - loss: 0.0520 - val_accuracy: 0.9885 - val_dice_coef: 0.6482 - val_iou_coef: 0.4819 - val_loss: 0.0381
# Epoch 10/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.9938 - dice_coef: 0.7081 - iou_coef: 0.5538 - loss: 0.0313 - val_accuracy: 0.9992 - val_dice_coef: 0.9060 - val_iou_coef: 0.8290 - val_loss: 0.0100

# %%
loss, accuracy, iou, dc = model.evaluate(X_test, Y_test)
print(f"test loss: {loss:.4f}, test accuracy: {accuracy:.4f}, dice coef: {dc}, iou coef: {iou}") #성능평가
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - accuracy: 0.9992 - dice_coef: 0.9059 - iou_coef: 0.8286 - loss: 0.0099
# test loss: 0.0100, test accuracy: 0.9992, dice coef: 0.9059687852859497, iou coef: 0.8288618922233582

# %%
preds = model.predict(X_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 698ms/step

# %%
def plot_results(X, Y_true, Y_pred, num_samples=5):
    plt.figure(figsize=(15, num_samples * 5))
    for i in range(num_samples):
        plt.subplot(num_samples, 3, i * 3 + 1)
        plt.imshow(X[i].squeeze(), cmap='gray')
        plt.title("Input Image")
        plt.axis('off')

        plt.subplot(num_samples, 3, i * 3 + 2)
        plt.imshow(Y_true[i].squeeze(), cmap='gray')
        plt.title("True Mask")
        plt.axis('off')

        plt.subplot(num_samples, 3, i * 3 + 3)
        plt.imshow(Y_pred[i].squeeze(), cmap='gray')
        plt.title("Predicted Mask")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
plot_results(X_test, Y_test, preds)
